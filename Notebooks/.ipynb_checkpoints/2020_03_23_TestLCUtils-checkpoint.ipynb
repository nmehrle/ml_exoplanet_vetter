# %% [markdown]
# # Routines to Test LC Utils

# %% [markdown]
# (1) Non-standard libraries required:
# - pyfits
#
# (2) Some files that need a "2to3 -w" conversion:
# - lctools/hd5flc/hdf5lc.py
# - tsig/lightcurve/lightcurve.py
#
# (3) Select data folder containing .h5 light curves

# %%
import sys, os
import numpy as np
import matplotlib.pyplot as plt

# Chelsea
sys.path.append('../Modules')
from lctools.hdf5lc import *
from tsig.lightcurve.lightcurve import FilebasedLightCurve

# For Astronet
from statsmodels.robust import scale

# %%
# Select data folder containing .h5 light curves
lcdatafolder = "../Data/2020_03_23_TestData/knownPlanets/"

# Identify all .h5 files inside data folder
lcdatafiles = os.listdir(lcdatafolder)

for lcdatafile in lcdatafiles:
    file_extension = lcdatafile.split(".")[-1]
    if file_extension != "h5":
        lcdatafiles.remove(lcdatafile)

nfiles = len(lcdatafiles)
print("Found {} lightcurves".format(nfiles))
# Out:
# Found 1 lightcurves

# %%
# Choose a lightcurve, 0 < i < nfiles - 1
i = 0

# Read in LC from .h5
filepath = lcdatafolder + lcdatafiles[i]
data1    = HDFLightCurve(name = filepath)
data1.load_from_file(dmagkey="KSPMagnitude")
all_time, all_mag = (data1.data["jd"],data1.data["ltflc"])

# Remove outliers
mad           = scale.mad(all_mag)
valid_indices = np.where(all_mag > np.median(all_mag)-5*mad)
all_mag       = all_mag[valid_indices]
all_time      = all_time[valid_indices]

# Convert mag to flux
all_flux = 10.**(-(all_mag - np.median(all_mag))/2.5)

# Phase fold
blsanal      = np.genfromtxt(filepath.replace("h5","blsanal"), 
                    dtype=float, delimiter=' ', names=True) 
period       = blsanal['BLS_Period_1_0']

half_period  = period / 2
folded_time  = np.mod(all_time + (half_period), period)
folded_time -= half_period

folded_time  = np.mod(all_time + (half_period), period)
folded_time -= half_period

sorted_i = np.argsort(folded_time)
folded_time = folded_time[sorted_i]
flux = all_flux[sorted_i]

# %%
plt.plot(folded_time,flux,'.')
plt.ylim([0.996,1.002])
# Out:
# (0.996, 1.002)
